# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Employee-Attrition.csv")
pd.set_option('display.max_columns',None)
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data["Education"].value_counts()
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %%
data["EnvironmentSatisfaction"].value_counts()
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
data["HourlyRate"].value_counts()
# Out:
# 66    29
# 98    28
# 42    28
# 48    28
# 84    28
#       ..
# 31    15
# 53    14
# 68    14
# 38    13
# 34    12
# Name: HourlyRate, Length: 71, dtype: int64

# %%
data['BusinessTravel'].replace({'Non-Travel':0,'Travel_Rarely':1,'Travel_Frequently': 2},inplace=True)
data["BusinessTravel"].value_counts()
# Out:
# 1    1043
# 2     277
# 0     150
# Name: BusinessTravel, dtype: int64

# %%
data['Attrition'].replace({'No':0,'Yes':1},inplace=True)
data['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
data["Department"].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
data["EducationField"].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
data['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
data['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
data['JobLevel'].value_counts()
# Out:
# 1    543
# 2    534
# 3    218
# 4    106
# 5     69
# Name: JobLevel, dtype: int64

# %%
data['JobInvolvement'].value_counts()
# Out:
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64

# %%
data['JobSatisfaction'].value_counts()
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64

# %%
data['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
data['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
data['Attrition'].replace({'No':0,'Yes':1},inplace=True)
data['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %% [markdown]
# # WHY DOES ATTRITION TAKE PLACE?
#
# Employees in a certain company may not be given tasks over a period of time just because they are not skilled enough or maybe because their previous record is poor. Hence, their job involvement will be very less, which is denoted by 1 and 2 in the job involvement column. People or employees with more job involvement, which is shown by 3 and for the job involvement column. Work more for the company, and as they have worked, they also might get paid better. Hence they have more motivation to stay and work for the company. If an employee isn't giving any job over the period of time, although the employee is earning money, the employee would like to leave because that would be a waste of time for their career.

# %%
data[['JobInvolvement', 'Attrition']].groupby(['JobInvolvement'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
# Out:
#    JobInvolvement  Attrition
# 0               1   0.337349
# 1               2   0.189333
# 2               3   0.144009
# 3               4   0.090278

# %% [markdown]
# The results are in sync with our hypothesis. Employees with the lowest job involvement, that is one have the highest probability of leaving the company, that is 0.33 . For a job involvement, waiting to almost 0.189 is the probability of attrition taking place. For job involvement rating 3 and 4, we can see that the probability of attrition for an employee is very less, which is 0.1 and 0.09 respectively. Hence, this is again in sync with our hypothesis that if people are more involved in jobs, then they are more likely to stay in the company.
#
# It is very human for people to go to places where they get more satisfaction and it is the same with employees. If they do not feel satisfied, they will not stay in the company. Let us check the validity of this statement.

# %%
c = data[['JobSatisfaction', 'Attrition']].groupby(['JobSatisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#    JobSatisfaction  Attrition
# 0                1   0.228374
# 2                3   0.165158
# 1                2   0.164286
# 3                4   0.113290

# %% [markdown]
# Again, the results are as we expected. 1 is the lowest level of job satisfaction. Employees with level 1 job satisfaction have the highest probability i.e. 0.22 of leaving the company, while the employees with highest job satisfaction 4, have the lowest probability of attrition.
#
# Another key factor, according to me, is the role of the job an employee has. An employee,may leave if he or she gets a better role in another company. This is mainly because normally a better role means higher salary.

# %%
c = data[['JobRole', 'Attrition']].groupby(['JobRole'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#                      JobRole  Attrition
# 8       Sales Representative   0.397590
# 2      Laboratory Technician   0.239382
# 1            Human Resources   0.230769
# 7            Sales Executive   0.174847
# 6         Research Scientist   0.160959
# 4     Manufacturing Director   0.068966
# 0  Healthcare Representative   0.068702
# 3                    Manager   0.049020
# 5          Research Director   0.025000

# %% [markdown]
# From the above output we can see that the roles which are normally of a higher position,such as "Scientist","Manager" and "Director" have the lowest probability of Attrition. Similarly, Sales Representatives are the most in number and by the looks of it, it is the lowest role. Hence, it has almost 0.4 probability of attrition.
#
# Now, let us check if the gender of the employee has any affect on attrition.

# %%
c = data[['Gender', 'Attrition']].groupby(['Gender'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#    Gender  Attrition
# 1    Male   0.170068
# 0  Female   0.147959

# %% [markdown]
# As expected, the gender doesn't really matter. Both gender's have almost equal probabilty of leaving the company.
#
# It is said that the environment of work matters a lot. If the work environment is stressful then people should be more prone towards attrition.

# %%
c = data[['EnvironmentSatisfaction', 'Attrition']].groupby(['EnvironmentSatisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#    EnvironmentSatisfaction  Attrition
# 0                        1   0.253521
# 1                        2   0.149826
# 2                        3   0.136865
# 3                        4   0.134529

# %% [markdown]
# The results we obtain are quite expected. Environment satisfaction 1 is the lowest and has the highest probability of attrition.
#
# Let us check if the Job level affects attrition.

# %%
c = data[['JobLevel', 'Attrition']].groupby(['JobLevel'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#    JobLevel  Attrition
# 0         1   0.263352
# 2         3   0.146789
# 1         2   0.097378
# 4         5   0.072464
# 3         4   0.047170

# %% [markdown]
# As expected, the employees at the higher levels have lower probavility of leaving the company.

# %%
c = data[['Age', 'Attrition']].groupby(['Age'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#     Age  Attrition
# 1    19   0.666667
# 2    20   0.545455
# 0    18   0.500000
# 3    21   0.461538
# 40   58   0.357143
# 4    22   0.312500
# 8    26   0.307692
# 10   28   0.291667
# 5    23   0.285714
# 6    24   0.269231
# 11   29   0.264706
# 13   31   0.260870
# 7    25   0.230769
# 38   56   0.214286
# 15   33   0.206897
# 26   44   0.181818
# 14   32   0.180328
# 34   52   0.166667
# 32   50   0.166667
# 12   30   0.150000
# 23   41   0.150000
# 21   39   0.142857
# 37   55   0.136364
# 17   35   0.128205
# 29   47   0.125000
# 28   46   0.121212
# 19   37   0.120000
# 16   34   0.116883
# 33   51   0.105263
# 35   53   0.105263
# 30   48   0.105263
# 22   40   0.087719
# 18   36   0.086957
# 31   49   0.083333
# 25   43   0.062500
# 9    27   0.062500
# 27   45   0.048780
# 24   42   0.043478
# 20   38   0.034483
# 36   54   0.000000
# 39   57   0.000000
# 41   59   0.000000
# 42   60   0.000000

# %%
c = data[['OverTime', 'Attrition']].groupby(['OverTime'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#   OverTime  Attrition
# 1      Yes   0.305288
# 0       No   0.104364

# %% [markdown]
# We can see that people who do overtime, they leave job.

# %%
c = data[['MaritalStatus', 'Attrition']].groupby(['MaritalStatus'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#   MaritalStatus  Attrition
# 2        Single   0.255319
# 1       Married   0.124814
# 0      Divorced   0.100917

# %% [markdown]
# Marital Status matters for attrition

# %%
c = data[['BusinessTravel', 'Attrition']].groupby(['BusinessTravel'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#    BusinessTravel  Attrition
# 2               2   0.249097
# 1               1   0.149569
# 0               0   0.080000

# %% [markdown]
# Business Travel matters for attrition

# %%
import seaborn as sns
g = sns.FacetGrid(data, col='Attrition')
g.map(plt.hist, 'MonthlyIncome', bins=20)

# %%
grid = sns.FacetGrid(data, col='Attrition', row='JobLevel', height=2.2, aspect=1.6)
grid.map(plt.hist, 'MonthlyIncome', alpha=.5, bins=20)
grid.add_legend();

# %% [markdown]
# There is a lot of information to unpack here -
#
# a. Let us first look at Attrition = 0, which means that attrition does not take place:-
#
# 1. For all the job levels, it is clearly visible that most of the employees of the company do not leave the company, i.e attrtion does not take place.
# 2. As we move from left to right in a certain graph, we also get to know that the number of employees decrease as we go higher up the income ladder.
#
# b. Now, looking at Attrition = 1
#
# 1. Most of the attrition takes place in the job levels 1 and 2.
# 2. Job level 3 has attrition but has lower attrition. This can be because the people of this job level, with certain amount of experience, can move into a new company and get a higher pay and move into a higher job level
# 3. Employees at Job levels 4 and 5 are generally very stable.This is why attrition is low. This is because employees at these levels, have high respect and most importantly, high pay.

# %%
grid = sns.FacetGrid(data, col='Attrition', row='JobRole', height=2.2, aspect=1.6)
grid.map(plt.hist, 'MonthlyIncome', alpha=.5, bins=20)
grid.add_legend();

# %% [markdown]
# We can see that attrition is most in case of Laboratory Technicians and Sales Executives. For positions such as Director, attrition is almost nil.

# %%
grid = sns.FacetGrid(data, col='Attrition', row='EnvironmentSatisfaction', height=2.2, aspect=1.6)
grid.map(plt.hist, 'MonthlyIncome', alpha=.5, bins=20)
grid.add_legend();

# %% [markdown]
# Here we can see that EnvironmentSatisfaction isn't really affecting attrition. Employees with low satisfaction and high salary tend to stay while ones who have high satisfaction but low salary, tend to leave.

# %% [markdown]
# # CREATING MEANINGFUL FEATURES

# %%
print(data[['JobSatisfaction', 'Attrition']].groupby(['JobSatisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False))
print(data[['RelationshipSatisfaction', 'Attrition']].groupby(['RelationshipSatisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False))
print(data[['EnvironmentSatisfaction', 'Attrition']].groupby(['EnvironmentSatisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False))
print(data[['WorkLifeBalance', 'Attrition']].groupby(['WorkLifeBalance'], as_index=False).mean().sort_values(by='Attrition', ascending=False))
# Out:
#    JobSatisfaction  Attrition
# 0                1   0.228374
# 2                3   0.165158
# 1                2   0.164286
# 3                4   0.113290
#    RelationshipSatisfaction  Attrition
# 0                         1   0.206522
# 2                         3   0.154684
# 1                         2   0.148515
# 3                         4   0.148148
#    EnvironmentSatisfaction  Attrition
# 0                        1   0.253521
# 1                        2   0.149826
# 2                        3   0.136865
# 3                        4   0.134529
#    WorkLifeBalance  Attrition
# 0                1   0.312500
# 3                4   0.176471
# 1                2   0.168605
# 2                3   0.142217

# %%
data["Satisfaction"] = (data["EnvironmentSatisfaction"]+data["JobSatisfaction"]+data["RelationshipSatisfaction"]+data["WorkLifeBalance"])//4
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0   41          1               1       1102                   Sales
# 1   49          0               2        279  Research & Development
# 2   37          1               1       1373  Research & Development
# 3   33          0               2       1392  Research & Development
# 4   27          0               1        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
print(data[['Satisfaction', 'Attrition']].groupby(['Satisfaction'], as_index=False).mean().sort_values(by='Attrition', ascending=False))
# Out:
#    Satisfaction  Attrition
# 0             1   0.323529
# 1             2   0.180124
# 2             3   0.118443
# 3             4   0.000000

# %% [markdown]
# The new feature Satisfaction, is more meaningful than the features with which it is made. It is also more correlated with the Attrition column

# %% [markdown]
# # ENCODING CATEGORICAL FEATURES

# %%
d = {'Sales Representative':0,'Laboratory Technician':1,'Human Resources':2, 'Sales Executive':3, 'Research Scientist':4,'Manufacturing Director':5,'Healthcare Representative':6,'Manager':7,'Research Director':8}
data['JobRole'].replace(d,inplace=True)
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0   41          1               1       1102                   Sales
# 1   49          0               2        279  Research & Development
# 2   37          1               1       1373  Research & Development
# 3   33          0               2       1392  Research & Development
# 4   27          0               1        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
data['Gender'].replace({'Male':0,'Female':1},inplace = True)
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0   41          1               1       1102                   Sales
# 1   49          0               2        279  Research & Development
# 2   37          1               1       1373  Research & Development
# 3   33          0               2       1392  Research & Development
# 4   27          0               1        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
d = {'Research & Development':0,'Sales':1,'Human Resources':2}
data['Department'].replace(d,inplace=True)
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               1       1102           1                 1
# 1   49          0               2        279           0                 8
# 2   37          1               1       1373           0                 2
# 3   33          0               2       1392           0                 3
# 4   27          0               1        591           0                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
# 3          4  Life Sciences              1               5
# 4          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %%
d = {'Travel_Rarely':0,'Travel_Frequently':1,'Non-Travel':2}
data['BusinessTravel'].replace(d,inplace=True)
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               1       1102           1                 1
# 1   49          0               2        279           0                 8
# 2   37          1               1       1373           0                 2
# 3   33          0               2       1392           0                 3
# 4   27          0               1        591           0                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
# 3          4  Life Sciences              1               5
# 4          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %%
d = {'Divorced':0,'Married':1,'Single':2}
data['MaritalStatus'].replace(d,inplace=True)
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               1       1102           1                 1
# 1   49          0               2        279           0                 8
# 2   37          1               1       1373           0                 2
# 3   33          0               2       1392           0                 3
# 4   27          0               1        591           0                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
# 3          4  Life Sciences              1               5
# 4          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %% [markdown]
# # FEATURE ENGINEERING

# %%
data["Satisfaction"] = (data["EnvironmentSatisfaction"]+data["JobSatisfaction"]+data["RelationshipSatisfaction"]+data["WorkLifeBalance"])//4
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               1       1102           1                 1
# 1   49          0               2        279           0                 8
# 2   37          1               1       1373           0                 2
# 3   33          0               2       1392           0                 3
# 4   27          0               1        591           0                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
# 3          4  Life Sciences              1               5
# 4          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %%
data["Years"] = (data["YearsAtCompany"]+data["YearsInCurrentRole"]+ data["YearsSinceLastPromotion"]+ data["YearsWithCurrManager"])//4
print(data.head())
data.corr()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               1       1102           1                 1
# 1   49          0               2        279           0                 8
# 2   37          1               1       1373           0                 2
# 3   33          0               2       1392           0                 3
# 4   27          0               1        591           0                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
# 3          4  Life Sciences              1               5
# 4          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %% [markdown]
# We get to see that the new feature "Years" is not as important for attrition as YearsInCurrentRole or YearsWithCurrManager is. Hence while modelling, we can neglect this feature.

# %%
data['OverTime'].replace({'No':0,'Yes':1},inplace=True)
data['OverTime'].value_counts()
# Out:
# 0    1054
# 1     416
# Name: OverTime, dtype: int64

# %%
correlation_matrix = data.corr()
correlation_with_attrition = correlation_matrix['Attrition'].sort_values(ascending=False)
print(correlation_with_attrition)
# Out:
# Attrition                   1.000000
# OverTime                    0.246118
# MaritalStatus               0.162070
# BusinessTravel              0.127006
# DistanceFromHome            0.077924
# Department                  0.077351
# NumCompaniesWorked          0.043494
# MonthlyRate                 0.015170
# PerformanceRating           0.002889
# HourlyRate                 -0.006846
# EmployeeNumber             -0.010577
# PercentSalaryHike          -0.013478
# Gender                     -0.029453
# Education                  -0.031373
# YearsSinceLastPromotion    -0.033019
# RelationshipSatisfaction   -0.045872
# DailyRate                  -0.056652
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# EnvironmentSatisfaction    -0.103369
# JobSatisfaction            -0.103481
# Satisfaction               -0.122787
# JobInvolvement             -0.130016
# YearsAtCompany             -0.134392
# StockOptionLevel           -0.137145
# ...

# %% [markdown]
# Positive Correlation: Values greater than 0 indicate a positive correlation, meaning that as the values in the other column increase, the likelihood of 'Attrition' also increases. For example, 'OverTime' has a positive correlation (0.246118), suggesting that employees who work overtime are more likely to experience attrition.
#
# Negative Correlation: Values less than 0 indicate a negative correlation, meaning that as the values in the other column increase, the likelihood of 'Attrition' decreases. For example, 'Age' has a negative correlation (-0.159205), indicating that older employees are less likely to experience attrition.
#
# Weak or No Correlation: Values close to 0 suggest a weak or no linear correlation. For columns with weak correlations, changes in those columns may not strongly affect the likelihood of attrition.
#
# Based on these correlation coefficients, you can make preliminary assessments of which columns may be more or less important in relation to attrition. For example, 'OverTime,' 'BusinessTravel,' and 'Age' seem to have relatively stronger correlations, while 'PerformanceRating,' 'HourlyRate,' and 'EmployeeNumber' have weak or no correlations with attrition.

# %%
data["NumCompaniesWorked"].value_counts()
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64

# %%
c = data[['NumCompaniesWorked', 'Attrition']].groupby(['NumCompaniesWorked'], as_index=False).mean().sort_values(by='Attrition', ascending=False)
print(c)
# Out:
#    NumCompaniesWorked  Attrition
# 5                   5   0.253968
# 9                   9   0.230769
# 7                   7   0.229730
# 6                   6   0.228571
# 1                   1   0.188100
# 8                   8   0.122449
# 4                   4   0.122302
# 0                   0   0.116751
# 2                   2   0.109589
# 3                   3   0.100629

# %%
def fn(n):
    a = []
    for i in n:
        if i>4:
            a.append(1)
        else:
            a.append(0)
    return a

# %%
data["NumComp"] = fn(data["NumCompaniesWorked"])
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               1       1102           1                 1
# 1   49          0               2        279           0                 8
# 2   37          1               1       1373           0                 2
# 3   33          0               2       1392           0                 3
# 4   27          0               1        591           0                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
# 1          1  Life Sciences              1               2
# 2          2          Other              1               4
# 3          4  Life Sciences              1               5
# 4          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       1          94               3         2
# ...

# %% [markdown]
# We can see that the new feature NumComp is much more correlated than NumCompaniesWorked. Although the value isn't very high, it can be used.

# %%
plt.figure(figsize= (30,20))
sns.heatmap(data.corr(),cmap = 'Dark2',annot = True,linewidths=1.0,linecolor='black')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7128\4000919213.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),cmap = 'Dark2',annot = True,linewidths=1.0,linecolor='black')
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# <Axes: >

# %%
plt.figure(figsize= (30,20))
sns.heatmap(np.abs(data.corr()),cmap = 'Dark2',annot = True,linewidths=1.0,linecolor='black')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7128\4052604916.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(np.abs(data.corr()),cmap = 'Dark2',annot = True,linewidths=1.0,linecolor='black')
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# <Axes: >

# %% [markdown]
# # MODEL CREATION

# %%
from sklearn.linear_model import LogisticRegression   
from sklearn.model_selection import KFold 
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics
from sklearn.metrics import accuracy_score , f1_score

# %% [markdown]
# Generic classification function

# %%
def classification_model(model, data, predictors, outcome):  
    #Fit the model:  
    model.fit(data[predictors],data[outcome])    
    #Make predictions on training set:  
    predictions = model.predict(data[predictors])    
    #Print accuracy  
    accuracy = metrics.accuracy_score(predictions,data[outcome])  
    print("Accuracy : %s" % "{0:.3%}".format(accuracy))
    #Perform k-fold cross-validation with 5 folds  
    kf = KFold(5,shuffle=True)  
    error = []  
    for train, test in kf.split(data):
        # Filter training data    
        train_predictors = (data[predictors].iloc[train,:])        
        # The target we're using to train the algorithm.    
        train_target = data[outcome].iloc[train]        
        # Training the algorithm using the predictors and target.    
        model.fit(train_predictors, train_target)
        #Record error from each cross-validation run    
        error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))
     
    score = f1_score(data[outcome], predictions, average="macro")
    print('F-Measure: %.3f' % score)
    print("Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error))) 
    # %s is placeholder for data from format, next % is used to conert it into percentage
    #.3% is no. of decimals
    return model

# %% [markdown]
# # Random Forest Classifier

# %%
output = 'Attrition'
model = RandomForestClassifier()
predict = ['Age', 'BusinessTravel', 'JobRole', 'JobSatisfaction', 'MaritalStatus','MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'YearsAtCompany']
classification_model(model,data,predict,output)
m = classification_model(model,data,predict,output)
# Out:
# Accuracy : 100.000%
# F-Measure: 1.000
# Cross-Validation Score : 85.646%
# Accuracy : 100.000%
# F-Measure: 1.000
# Cross-Validation Score : 85.646%

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
output = 'Attrition'
model = LogisticRegression(solver='lbfgs', max_iter=1000)
predict = ['Age', 'BusinessTravel', 'JobRole', 'JobSatisfaction', 'MaritalStatus','MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'YearsAtCompany']
classification_model(model,data,predict,output)
m = classification_model(model,data,predict,output)
# Out:
# Accuracy : 86.463%
# F-Measure: 0.661
# Cross-Validation Score : 86.463%
# Accuracy : 86.463%
# F-Measure: 0.661
# Cross-Validation Score : 86.190%

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn import svm
output = 'Attrition'
model = svm.SVC()
predict = ['Age', 'BusinessTravel', 'JobRole', 'JobSatisfaction', 'MaritalStatus','MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'YearsAtCompany']
classification_model(model,data,predict,output)
m = classification_model(model,data,predict,output)
# Out:
# Accuracy : 83.878%
# F-Measure: 0.456
# Cross-Validation Score : 83.878%
# Accuracy : 83.878%
# F-Measure: 0.456
# Cross-Validation Score : 83.878%

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Perceptron

# %%
from sklearn.linear_model import Perceptron
output = 'Attrition'
model = Perceptron()
predict = ['Age', 'BusinessTravel', 'JobRole', 'JobSatisfaction', 'MaritalStatus','MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'YearsAtCompany'] 
classification_model(model,data,predict,output)
m = classification_model(model,data,predict,output)
# Out:
# Accuracy : 83.878%
# F-Measure: 0.456
# Cross-Validation Score : 70.000%
# Accuracy : 83.878%
# F-Measure: 0.456
# Cross-Validation Score : 83.878%

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score


output = 'Attrition'
predict = ['Age', 'BusinessTravel', 'JobRole', 'JobSatisfaction', 'MaritalStatus','MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'YearsAtCompany']
X_train, X_test, Y_train, Y_test = train_test_split(data[predict], data[output], test_size=0.3)
D_train = xgb.DMatrix(X_train, label=Y_train)
D_test = xgb.DMatrix(X_test, label=Y_test)
param = {
    'eta': 0.3, 
    'max_depth': 3,  
    'objective': 'multi:softprob',  
    'num_class': 3} 

steps = 20
model = xgb.train(param, D_train, steps)
preds = model.predict(D_test)
best_preds = np.asarray([np.argmax(line) for line in preds])

print("Accuracy = {}".format(accuracy_score(Y_test, best_preds)))
print("f1 score = {}".format(f1_score(Y_test, best_preds)))
# Out:
# Accuracy = 0.8571428571428571
# f1 score = 0.3505154639175258

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

output = 'Attrition'
predict = ['Age', 'BusinessTravel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
           'MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'YearsAtCompany']

X_train, X_test, Y_train, Y_test = train_test_split(data[predict], data[output], test_size=0.3)

model = LGBMClassifier()
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)

print("Accuracy: {:.3f}".format(accuracy))
print("F1 Score: {:.3f}".format(f1))
# Out:
# [LightGBM] [Info] Number of positive: 180, number of negative: 849
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000138 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 360
# [LightGBM] [Info] Number of data points in the train set: 1029, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.174927 -> initscore=-1.551102
# [LightGBM] [Info] Start training from score -1.551102
# Accuracy: 0.878
# F1 Score: 0.460

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score
from tabulate import tabulate


# Specify the output variable and predictor columns
output = 'Attrition'
predict = ['Age', 'BusinessTravel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
           'MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'YearsAtCompany']

# Create a dictionary to store model names and metrics
model_metrics = {
    'Model': ['Logistic Regression', 'Random Forest', 'SVM', 'Perceptron', 'LightGBM', 'XGBoost'],
    'Accuracy': [],
    'F1 Score': []
}

# Add models and calculate metrics
for model_name in model_metrics['Model']:
    if model_name == 'Logistic Regression':
        # Create and train the logistic regression model
        model = LogisticRegression(solver='lbfgs', max_iter=1000)
    elif model_name == 'Random Forest':
        # Create and train the random forest model
        model = RandomForestClassifier()
    elif model_name == 'SVM':
        # Create and train the SVM model
        model = svm.SVC()
    elif model_name == 'Perceptron':
        # Create and train the Perceptron model
        model = Perceptron()
    elif model_name == 'LightGBM':
        # Create and train the LightGBM model
        model = LGBMClassifier()
    elif model_name == 'XGBoost':
        # Create and train the XGBoost model
        model = xgb.XGBClassifier()

    # Train the model
    model.fit(data[predict], data[output])

    # Make predictions
    predictions = model.predict(X_test)

    # Calculate accuracy and F1 score
    accuracy = accuracy_score(Y_test, predictions)
    f1 = f1_score(Y_test, predictions)

    # Append metrics to the dictionary
    model_metrics['Accuracy'].append(accuracy)
    model_metrics['F1 Score'].append(f1)

# Create a Pandas DataFrame from the dictionary
df = pd.DataFrame(model_metrics)

# Rank models by accuracy (highest to lowest)
df['Rank by Accuracy'] = df['Accuracy'].rank(ascending=False)

# Display the table
print(tabulate(df.sort_values(by='Rank by Accuracy'), headers='keys', tablefmt='grid'))
# Out:
# [LightGBM] [Info] Number of positive: 237, number of negative: 1233
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 363
# [LightGBM] [Info] Number of data points in the train set: 1470, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.161224 -> initscore=-1.649145
# [LightGBM] [Info] Start training from score -1.649145
# +----+---------------------+------------+------------+--------------------+
# |    | Model               |   Accuracy |   F1 Score |   Rank by Accuracy |
# +====+=====================+============+============+====================+
# |  1 | Random Forest       |   1        |   1        |                2   |
# +----+---------------------+------------+------------+--------------------+
# ...

# %%
pip install tabulate
